# %% [markdown]
# ## Creating a basemap of Washington D.C. to use for the analysis

# %% [markdown]
# initializing basic world map

# %%
#Importing libraries
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

map = Basemap()
map.drawcoastlines()

plt.show()

# %% [markdown]
# default map uses Plate Carree proejction centered at (lon., lat.)= (0,0)

# %%
#Importing libraries
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

map.drawmapboundary(fill_color= 'aqua') #fills map with aqua
map.fillcontinents(color='coral', lake_color='aqua') #fills continents with coral and lakes with aqua
plt.show()

# %% [markdown]
# Same map, but now lakes and oceans are "aqua" and land is "coral"

# %%
#Importing libraries
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

map = Basemap(lat_0= 38.8951100, lon_0= -77.0363700)
map.drawcoastlines()
map.drawmapboundary(fill_color= 'aqua') #fills map with aqua
map.fillcontinents(color='coral', lake_color='aqua') #fills continents with coral and lakes with aqua

x, y= map(-77.0363700, 38.8951100)
map.plot(x, y, marker="o", color='m')

plt.show()

# %% [markdown]
# same map, centered on washington DC (purple circle) lat_1=45.,lat_2=55

# %%
#Importing libraries
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

map = Basemap(lat_1=45.,lat_2=55,lat_0= 38.8951100, lon_0= -77.0363700)
map.drawcoastlines()
map.drawmapboundary(fill_color= 'aqua') #fills map with aqua
map.fillcontinents(color='coral', lake_color='aqua') #fills continents with coral and lakes with aqua

x, y= map(-77.0363700, 38.8951100)
map.plot(x, y, marker="o", color='m')

plt.show()

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
# setup Lambert Conformal basemap.
# set resolution=None to skip processing of boundary datasets.
map = Basemap(resolution= 'f',projection= 'aea',width=1200000,height=900000,lat_1=45.,lat_2=55,lat_0= 38.8951100, lon_0= -77.0363700)
map.drawcoastlines()
map.drawmapboundary(fill_color= 'aqua') #fills map with aqua
map.fillcontinents(color='coral', lake_color='aqua') #fills continents with coral and lakes with aqua

x, y= map(-77.0363700, 38.8951100)
map.plot(x, y, marker="o", color='m')

plt.show()

# %% [markdown]
# using aea (equal area projection as suggested by: (cite)). note significant distorion near polls

# %% [markdown]
# need shape file or other method of marking DC boundary and then Ward 1 boundary:
# map.readshapefile('../sample_files/comarques', 'comarques')

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
# setup Lambert Conformal basemap.
# set resolution=None to skip processing of boundary datasets.
map = Basemap(resolution= 'f',projection= 'aea',width=12000,height=9000,lat_1=45.,lat_2=55,lat_0= 38.8951100, lon_0= -77.0363700)
map.drawcoastlines()
map.drawmapboundary(fill_color= 'aqua') #fills map with aqua
map.fillcontinents(color='coral', lake_color='aqua') #fills continents with coral and lakes with aqua

x, y= map(-77.0363700, 38.8951100)
map.plot(x, y, marker="o", color='m')

map.readshapefile('D:\OneDrive - University of South Carolina - Moore School of Business\DC_crime\Data\Ward_from_2012\Ward_from_2012', 'ward_shapefile')

plt.show()

# %% [markdown]
# using shape file from http://opendata.dc.gov/datasets/ward-from-2012/data this map shows Washington DC with ward divisions

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
# setup Lambert Conformal basemap.
# set resolution=None to skip processing of boundary datasets.
map = Basemap(resolution= 'f',projection= 'aea',llcrnrlon=-77.12059, llcrnrlat= 38.788345, urcrnrlon=-76.904984, urcrnrlat=38.995173,lat_0= 38.8951100, lon_0= -77.0363700)
map.drawcoastlines()
map.drawmapboundary(fill_color= 'aqua') #fills map with aqua
map.fillcontinents(color='coral', lake_color='aqua') #fills continents with coral and lakes with aqua

map.readshapefile('D:\OneDrive - University of South Carolina - Moore School of Business\DC_crime\Data\Ward_from_2012\Ward_from_2012', 'ward_shapefile')

x, y= map(-77.0363700, 38.8951100)
map.plot(x, y, marker="o", color='m')

plt.show()

# %% [markdown]
# using westlimit=-77.12059; southlimit=38.788345; eastlimit=-76.904984; northlimit=38.995173 to display only Washington DC. this information was accessed from http://boundingbox.klokantech.com/

# %% [markdown]
# need to zoom in ward 1:smallest ward, just above center
#
# see: http://basemaptutorial.readthedocs.io/en/latest/shapefile.html

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
# setup Lambert Conformal basemap.
# set resolution=None to skip processing of boundary datasets.
map = Basemap(resolution= 'f',projection= 'aea',llcrnrlon=-77.12059, llcrnrlat= 38.788345, urcrnrlon=-76.904984, urcrnrlat=38.995173,lat_0= 38.8951100, lon_0= -77.0363700)
map.drawcoastlines()
map.drawmapboundary(fill_color= 'aqua') #fills map with aqua
map.fillcontinents(color='coral', lake_color='aqua') #fills continents with coral and lakes with aqua

map.readshapefile('D:\OneDrive - University of South Carolina - Moore School of Business\DC_crime\Data\Ward_from_2012\Ward_from_2012', 'ward_shapefile', drawbounds = False)

x, y= map(-77.0363700, 38.8951100)
map.plot(x, y, marker="o", color='m')

for info, shape in zip(map.ward_shapefile_info, map.ward_shapefile):
    if info['WARD'] == 1:
        x, y = zip(*shape) 
        map.plot(x, y, marker=None,color='m')

plt.show()

# %% [markdown]
# This gives only the ward 1 boundary...need to zoom in

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
# setup Lambert Conformal basemap.
# set resolution=None to skip processing of boundary datasets.
map = Basemap(resolution= 'f',projection= 'aea',llcrnrlon=-77.051325, llcrnrlat= 38.913931, urcrnrlon=-77.0121, urcrnrlat=38.938311,lat_0= 38.926139, lon_0= -77.031688)
map.drawcoastlines()
map.drawmapboundary(fill_color= 'aqua') #fills map with aqua
map.fillcontinents(color='coral', lake_color='aqua') #fills continents with coral and lakes with aqua

map.readshapefile('D:\OneDrive - University of South Carolina - Moore School of Business\DC_crime\Data\Ward_from_2012\Ward_from_2012', 'ward_shapefile', drawbounds = False)

x, y= map(-77.0363700, 38.8951100)
map.plot(x, y, marker="o", color='m')

for info, shape in zip(map.ward_shapefile_info, map.ward_shapefile):
    if info['WARD'] == 1:
        x, y = zip(*shape) 
        map.plot(x, y, marker=None,color='m')

plt.show()

# %% [markdown]
# westlimit=-77.051325; southlimit=38.913931; eastlimit=-77.0121; northlimit=38.938311 as rough border of ward 1 and 38.926139, -77.031688 as center by comparing https://www.google.com/maps/d/viewer?mid=1DpJu2DbYssvxH0XsK6f6iXV6BN4&hl=en_US&ll=38.92545661000064%2C-77.01419448928834&z=17 and plotting box on http://boundingbox.klokantech.com/ by hand.

# %% [markdown]
# Need to draw features

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import os
# setup Lambert Conformal basemap.
# set resolution=None to skip processing of boundary datasets.
plt.figure(figsize=(24, 12))

map = Basemap(resolution= 'f',projection= 'aea',llcrnrlon=-77.051325, llcrnrlat= 38.913931, urcrnrlon=-77.0121, urcrnrlat=38.938311,lat_0= 38.926139, lon_0= -77.031688)
map.drawcoastlines()
map.drawmapboundary(fill_color= 'aqua') #fills map with aqua
map.fillcontinents(color='coral', lake_color='aqua') #fills continents with coral and lakes with aqua

os.chdir(r'D:\OneDrive - University of South Carolina - Moore School of Business\DC_crime\Data\Ward_from_2012')

map.readshapefile('Ward_from_2012', 'ward_shapefile', drawbounds = False)

os.chdir(r'D:\OneDrive - University of South Carolina - Moore School of Business\DC_crime\Data\geofabrik')

map.readshapefile('roads_free_1', 'roads')

x, y= map(-77.0363700, 38.8951100)
map.plot(x, y, marker="o", color='m')

for info, shape in zip(map.ward_shapefile_info, map.ward_shapefile):
    if info['WARD'] == 1:
        x, y = zip(*shape) 
        map.plot(x, y, marker=None,color='m')

plt.show()

# %% [markdown]
# testing road shape files from http://download.geofabrik.de/north-america/us/district-of-columbia.html

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import os
# setup Lambert Conformal basemap.
# set resolution=None to skip processing of boundary datasets.
plt.figure(figsize=(24, 12))

map = Basemap(resolution= 'h',projection= 'aea',llcrnrlon=-77.051325, llcrnrlat= 38.913931, urcrnrlon=-77.0121, urcrnrlat=38.938311,lat_0= 38.926139, lon_0= -77.031688)
map.drawcoastlines()
map.drawmapboundary(fill_color= 'aqua') #fills map with aqua
map.fillcontinents(color='white', lake_color='aqua') #fills continents with coral and lakes with aqua

os.chdir(r'D:\OneDrive - University of South Carolina - Moore School of Business\DC_crime\Data\Ward_from_2012')

map.readshapefile('Ward_from_2012', 'ward_shapefile', drawbounds = False)

os.chdir(r'D:\OneDrive - University of South Carolina - Moore School of Business\DC_crime\Data\geofabrik')

map.readshapefile('roads_free_1', 'roads')

map.readshapefile('buildings_a_free_1', 'buildings')


for info, shape in zip(map.ward_shapefile_info, map.ward_shapefile):
    if info['WARD'] == 1:
        x, y = zip(*shape) 
        map.plot(x, y, marker=None,color='m')

plt.show()

# %% [markdown]
# includes buildings

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import os
# setup Lambert Conformal basemap.
# set resolution=None to skip processing of boundary datasets.
plt.figure(figsize=(36, 18))

map = Basemap(resolution= 'f',projection= 'aea',llcrnrlon=-77.051325, llcrnrlat= 38.913931, urcrnrlon=-77.0121, urcrnrlat=38.938311,lat_0= 38.926139, lon_0= -77.031688)
map.drawcoastlines()
map.drawmapboundary(fill_color= 'aqua') #fills map with aqua
map.fillcontinents(color='white', lake_color='aqua') #fills continents with coral and lakes with aqua

os.chdir(r'D:\OneDrive - University of South Carolina - Moore School of Business\DC_crime\Data\Ward_from_2012')

map.readshapefile('Ward_from_2012', 'ward_shapefile', drawbounds = False)

os.chdir(r'D:\OneDrive - University of South Carolina - Moore School of Business\DC_crime\Data\geofabrik')

map.readshapefile('roads_free_1', 'roads')

map.readshapefile('buildings_a_free_1', 'buildings')

map.readshapefile('water_a_free_1', 'water1')

map.readshapefile('waterways_free_1', 'water2')

for info, shape in zip(map.ward_shapefile_info, map.ward_shapefile):
    if info['WARD'] == 1:
        x, y = zip(*shape) 
        map.plot(x, y, marker=None,color='m')

plt.show()

# %% [markdown]
# preliminary basemap, full res
